# %%
import pandas as pd
import numpy as np
import random

# %%
amostra=[random.randint(1,99) for I in range (20)]
print(amostra)
dados=np.array(amostra)
print(dados)
# Out:
# [62, 19, 83, 31, 61, 27, 65, 6, 73, 16, 71, 9, 36, 52, 58, 31, 96, 57, 77, 37]
# [62 19 83 31 61 27 65  6 73 16 71  9 36 52 58 31 96 57 77 37]

# %%
#calculo do quartis:

q1=np.percentile(dados,25) #o rpimeiro quartil representa 25% do tatal da amostra 
q2=np.percentile(dados,50) # mediana pode ser representada como o seu segundo quartil (quartil 50)
q3=np.percentile(dados,75) # o terceiro quartil representa 75% do total da amostra 

#exibição

print(f"primeiro quartil (q1):{q1}")
print(f"segundo quartil (q2):{q2}")
print(f"terceiro quartil (q1):{q1}")
# Out:
# primeiro quartil (q1):30.0
# segundo quartil (q2):54.5
# terceiro quartil (q1):30.0

# %% [markdown]
# Atividade

# %% [markdown]
# Gráficos - biblioteca MatPlotlib

# %%
import pandas as pd
import numpy as np
import random

# %%
amostra=[random.randint(1,99) for i in range(20)]
dados=np.array(amostra)
print(dados)
# Out:
# [74 20 63 21 58 20 62  4 29 72 53 31 94 91 27  6 29 38 40 47]

# %%
q1=np.percentile(dados,25) # o primeiro quartil representa 25% do total da amostra
q2=np.percentile(dados,50) # mediana pode ser interpretada como o seu segundo quartil (quartil 50)
q3=np.percentile(dados,75) # o terceiro quartil representa 75% do total da amostra

#Exibição:

print(f"Primeiro Quartil (Q1):{q1}")
print(f"Segundo Quartil (Q2):{q2}")
print(f"Terceiro Quartil (Q3):{q3}")
# Out:
# Primeiro Quartil (Q1):25.5
# Segundo Quartil (Q2):39.0
# Terceiro Quartil (Q3):62.25

# %% [markdown]
# ATIVIDADE EM AULA: Calcule os Quartis do dataset nutricional trabalhado na aula anterior, exibindo-os em seguida.

# %%
#LEMBRE-SE: no terminal, rodar 'pip install matplotlib'
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.bar(range(1,21),dados, color='purple')
plt.xlabel('Índices')
plt.ylabel('Valores Aleatórios')
plt.title('Gráfico de Barras dos 20 Números Aleatórios')
plt.xticks(range(1,21))
plt.show()
