# %%
import pandas as pd
import numpy as np
import random

# %%
amostra=[random.randint(1, 444) for I in range (50)]
print(amostra)
dados=np.array(amostra)
print(dados)
# Out:
# [45, 277, 135, 311, 341, 64, 323, 357, 272, 444, 83, 143, 431, 1, 194, 244, 27, 150, 156, 353, 173, 122, 210, 148, 316, 105, 434, 86, 61, 74, 107, 78, 204, 437, 382, 278, 389, 412, 152, 128, 34, 432, 438, 190, 318, 163, 338, 5, 421, 32]
# [ 45 277 135 311 341  64 323 357 272 444  83 143 431   1 194 244  27 150
#  156 353 173 122 210 148 316 105 434  86  61  74 107  78 204 437 382 278
#  389 412 152 128  34 432 438 190 318 163 338   5 421  32]

# %%
amostra_df=pd.DataFrame(amostra,columns=['valores'])
print(amostra_df)
# Out:
#     valores
# 0        45
# 1       277
# 2       135
# 3       311
# 4       341
# 5        64
# 6       323
# 7       357
# 8       272
# 9       444
# 10       83
# 11      143
# 12      431
# 13        1
# 14      194
# 15      244
# 16       27
# 17      150
# 18      156
# 19      353
# 20      173
# 21      122
# 22      210
# 23      148
# 24      316
# 25      105
# 26      434
# 27       86
# 28       61
# 29       74
# 30      107
# 31       78
# 32      204
# 33      437
# 34      382
# 35      278
# 36      389
# 37      412
# 38      152
# 39      128
# 40       34
# 41      432
# 42      438
# 43      190
# 44      318
# 45      163
# 46      338
# 47        5
# 48      421
# 49       32

# %%
#Medidas de disposição
valor_maximo=amostra_df['valores'].max()
valor_minimo=amostra_df['valores'].min()
amplitude_total=valor_maximo-valor_minimo

print(f'menor valor:{valor_maximo}')
print(f'maior valor:{valor_maximo}')
print(f'amplitude:{valor_maximo}')
# Out:
# menor valor:444
# maior valor:444
# amplitude:444

# %%
import matplotlib.pyplot as plt
#configuração do painel 
fig,ax=plt.subplots(1,2,figsize=(12,6))

#Boxplot
ax[0].boxplot(amostra_df['valores'])
ax[0].set_title('distribuição de dados - Boxplot')
ax[0].set_ylabel('valores')

#exibindo as medidas
ax[1].text(0.1,0.8,f"menor valor:{valor_minimo}")
ax[1].text(0.1,0.7,f"maior valor:{valor_maximo}")
ax[1].text(0.1,0.6,f"menor valor:{amplitude_total}")
ax[1].set_axis_off()

plt.tight_layout()
plt.show()
